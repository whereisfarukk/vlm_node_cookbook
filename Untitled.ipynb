// %%
// Cell 1: Import and setup
import { VlmRun } from "vlmrun";

const API_KEY = "7R8aQ5XlH00LlGdlpe_SLywfsAwszz";
const client = new VlmRun({ apiKey: API_KEY });

// Cell 2: Process an image
const imageUrl = "https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.invoice/invoice_1.jpg";

const result = await client.image.generate({
  images: [imageUrl],
  domain: "document.invoice",
});

console.log(result.response);

// %%
console.log('hellow');
